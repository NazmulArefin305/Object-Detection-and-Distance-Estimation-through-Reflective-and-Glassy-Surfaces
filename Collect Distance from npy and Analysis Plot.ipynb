# %%
import cv2
import numpy as np
from ultralytics import YOLO
import os
import glob
import csv

# Load YOLOv8 model
model = YOLO('assignment_3_model_yolo11s.pt')

# Root folder
#base_folder = r"F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\captured_images2\Scenario_3\Place_1\Object_100\Distance_d11"
#base_folder = r"F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\captured_images2\Scenario_2\Place_1\Object_100\Distance_d11"
base_folder = r"F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\captured_images2\Scenario_1\Place_1\Object_100\Distance_d11"


# Subfolder paths
rgb_folder = os.path.join(base_folder, "RGB")
npy_folder = os.path.join(base_folder, "NPY")
csv_output_path = os.path.join(base_folder, "object_distances.csv")

# RealSense D455: convert mm to meters
depth_scale = 0.001

# Target object names (CSV column headers)
expected_classes = [
    "apple", "watch", "airpods", "card", "mouse",
    "plug", "stapler", "orange", "phone", "stickypad"
]

# Mapping from YOLO class names to expected CSV column names
class_name_map = {
    "Apple": "apple",
    "Watch": "watch",
    "AirPod": "airpods",
    "CardHolder": "card",
    "Mouse": "mouse",
    "Key": "plug",
    "Stapler": "stapler",
    "Orange": "orange",
    "Mobile": "phone",
    "StickyNote": "stickypad"
}

# List all RGB files
rgb_files = sorted(glob.glob(os.path.join(rgb_folder, "rgb_frame_*.png")))

# Write to CSV
with open(csv_output_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["image"] + expected_classes)

    for rgb_path in rgb_files:
        index = os.path.splitext(os.path.basename(rgb_path))[0].split("_")[-1]
        depth_path = os.path.join(npy_folder, f"depth_raw_{index}.npy")

        if not os.path.exists(depth_path):
            print(f"[Warning] Missing depth file for: {rgb_path}")
            continue

        # Load images
        rgb_image = cv2.imread(rgb_path)
        depth_image = np.load(depth_path).astype(np.float32) * depth_scale

        # Run object detection
        results = model(rgb_image)
        object_depths = {cls: "" for cls in expected_classes}

        for result in results:
            boxes = result.boxes
            for box in boxes:
                x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
                confidence = box.conf[0].cpu().numpy()
                class_id = int(box.cls[0].cpu().numpy())
                detected_name = model.names[class_id]
                class_name = class_name_map.get(detected_name, None)

                if confidence < 0.5 or class_name is None:
                    continue

                # Get valid depth pixels
                crop = depth_image[y1:y2, x1:x2]
                valid_depths = crop[(crop > 0) & (crop < 10)]
                if valid_depths.size == 0:
                    continue

                # Store median depth
                object_depths[class_name] = round(np.median(valid_depths*0.92), 3)

        # Write one row to CSV
        row = [os.path.basename(rgb_path)] + [object_depths[cls] for cls in expected_classes]
        writer.writerow(row)

print(f"✅ CSV saved: {csv_output_path}")
# Out:
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 145.6ms
# Speed: 4.4ms preprocess, 145.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 150.4ms
# Speed: 2.1ms preprocess, 150.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 137.3ms
# Speed: 2.1ms preprocess, 137.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 138.7ms
# Speed: 1.8ms preprocess, 138.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 137.6ms
# Speed: 2.3ms preprocess, 137.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 144.1ms
# Speed: 2.2ms preprocess, 144.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 125.1ms
# Speed: 1.8ms preprocess, 125.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 137.3ms
# Speed: 2.0ms preprocess, 137.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 122.9ms
# Speed: 1.6ms preprocess, 122.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 121.9ms
# Speed: 2.5ms preprocess, 121.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 119.1ms
# Speed: 1.7ms preprocess, 119.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 135.7ms
# Speed: 2.1ms preprocess, 135.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 143.3ms
# Speed: 2.6ms preprocess, 143.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 141.1ms
# Speed: 1.8ms preprocess, 141.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 144.5ms
# Speed: 1.7ms preprocess, 144.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 135.1ms
# Speed: 1.7ms preprocess, 135.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 146.6ms
# Speed: 2.0ms preprocess, 146.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 130.9ms
# Speed: 1.5ms preprocess, 130.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 157.6ms
# Speed: 3.0ms preprocess, 157.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 147.7ms
# Speed: 2.1ms preprocess, 147.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 128.7ms
# Speed: 2.1ms preprocess, 128.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 142.2ms
# Speed: 2.9ms preprocess, 142.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 134.4ms
# Speed: 1.7ms preprocess, 134.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 132.9ms
# Speed: 2.4ms preprocess, 132.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 130.2ms
# Speed: 3.0ms preprocess, 130.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 131.4ms
# Speed: 1.5ms preprocess, 131.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 138.8ms
# Speed: 2.5ms preprocess, 138.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 139.2ms
# Speed: 2.1ms preprocess, 139.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 148.1ms
# Speed: 2.6ms preprocess, 148.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 138.8ms
# Speed: 2.0ms preprocess, 138.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 148.6ms
# Speed: 2.4ms preprocess, 148.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 122.2ms
# Speed: 3.4ms preprocess, 122.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 136.2ms
# Speed: 3.1ms preprocess, 136.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ CSV saved: F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\captured_images2\Scenario_1\Place_1\Object_100\Distance_d11\object_distances.csv

# %%
#Loop over all folders for distance values in csv
#Experiment final (15/04/25)

# %%
import cv2
import numpy as np
from ultralytics import YOLO
import os
import glob
import csv

# ✅ Load YOLOv8 model
model = YOLO('assignment_3_model_yolo11s.pt')

# ✅ Updated root directory
base_root = r"F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation"

# ✅ RealSense D455: meters
depth_scale = 0.001

# ✅ Expected CSV headers
expected_classes = [
    "apple", "watch", "airpods", "cardholder", "mouse",
    "key", "stapler", "orange", "phone", "stickynote"
]

# ✅ Mapping YOLO class names to target column names
class_name_map = {
    "Apple": "apple",
    "Watch": "watch",
    "AirPod": "airpods",
    "CardHolder": "cardholder",
    "Mouse": "mouse",
    "Key": "key",
    "Stapler": "stapler",
    "Orange": "orange",
    "Mobile": "phone",
    "StickyNote": "stickynote"
}

# ✅ Iterate through all scenarios and places
for scenario in range(1, 4):
    for place in range(1, 4):
        print(f"🔍 Processing Scenario_{scenario}, Place_{place}...")

        # Construct paths
        place_folder = os.path.join(base_root, f"Scenario_{scenario}", f"Place_{place}")
        rgb_folder = os.path.join(place_folder, "RGB")
        npy_folder = os.path.join(place_folder, "NPY")
        csv_output_path = os.path.join(place_folder, "object_distances.csv")

        # Check existence
        if not os.path.exists(rgb_folder) or not os.path.exists(npy_folder):
            print(f"⚠️ Skipping: Missing RGB or NPY folder in {place_folder}")
            continue

        # List RGB frames
        rgb_files = sorted(glob.glob(os.path.join(rgb_folder, "rgb_frame_*.png")))
        if not rgb_files:
            print(f"⚠️ No RGB images found in: {rgb_folder}")
            continue

        # Write CSV
        with open(csv_output_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["image"] + expected_classes)

            for rgb_path in rgb_files:
                index = os.path.splitext(os.path.basename(rgb_path))[0].split("_")[-1]
                depth_path = os.path.join(npy_folder, f"depth_raw_{index}.npy")

                if not os.path.exists(depth_path):
                    print(f"[Warning] Missing depth file for: {rgb_path}")
                    continue

                # Load data
                rgb_image = cv2.imread(rgb_path)
                depth_image = np.load(depth_path).astype(np.float32) * depth_scale

                # Run object detection
                results = model(rgb_image)
                object_depths = {cls: "" for cls in expected_classes}

                for result in results:
                    for box in result.boxes:
                        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy().astype(int)
                        confidence = box.conf[0].cpu().numpy()
                        class_id = int(box.cls[0].cpu().numpy())
                        detected_name = model.names[class_id]
                        class_name = class_name_map.get(detected_name, None)

                        if confidence < 0.5 or class_name is None:
                            continue

                        # Extract depth region
                        crop = depth_image[y1:y2, x1:x2]
                        valid_depths = crop[(crop > 0) & (crop < 10)]
                        if valid_depths.size == 0:
                            continue

                        # Save median distance (adjusted by 0.92 factor)
                        object_depths[class_name] = round(np.median(valid_depths * 0.92), 3)

                # Write one row to CSV
                row = [os.path.basename(rgb_path)] + [object_depths[cls] for cls in expected_classes]
                writer.writerow(row)

        print(f"✅ CSV saved at: {csv_output_path}")
# Out:
# 🔍 Processing Scenario_1, Place_1...
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 420.0ms
# Speed: 8.7ms preprocess, 420.0ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 398.4ms
# Speed: 4.4ms preprocess, 398.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 408.6ms
# Speed: 4.1ms preprocess, 408.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 404.7ms
# Speed: 4.5ms preprocess, 404.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 447.5ms
# Speed: 4.7ms preprocess, 447.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 385.1ms
# Speed: 4.2ms preprocess, 385.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 401.3ms
# Speed: 3.4ms preprocess, 401.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 366.6ms
# Speed: 3.2ms preprocess, 366.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 378.6ms
# Speed: 2.7ms preprocess, 378.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 396.4ms
# Speed: 2.6ms preprocess, 396.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 379.8ms
# Speed: 4.1ms preprocess, 379.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 417.0ms
# Speed: 2.7ms preprocess, 417.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 439.9ms
# Speed: 3.8ms preprocess, 439.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 474.2ms
# Speed: 3.8ms preprocess, 474.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 428.3ms
# Speed: 4.8ms preprocess, 428.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 438.0ms
# Speed: 4.7ms preprocess, 438.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 434.5ms
# Speed: 5.0ms preprocess, 434.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 425.3ms
# Speed: 3.8ms preprocess, 425.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 405.1ms
# Speed: 4.7ms preprocess, 405.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 462.5ms
# Speed: 5.6ms preprocess, 462.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 424.5ms
# Speed: 4.9ms preprocess, 424.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 450.1ms
# Speed: 3.9ms preprocess, 450.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 425.2ms
# Speed: 3.7ms preprocess, 425.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 408.4ms
# Speed: 5.2ms preprocess, 408.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 457.6ms
# Speed: 4.3ms preprocess, 457.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 380.1ms
# Speed: 3.9ms preprocess, 380.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 368.3ms
# Speed: 2.6ms preprocess, 368.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 395.4ms
# Speed: 3.4ms preprocess, 395.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 400.8ms
# Speed: 4.0ms preprocess, 400.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 422.1ms
# Speed: 2.6ms preprocess, 422.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 436.5ms
# Speed: 4.2ms preprocess, 436.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 418.2ms
# Speed: 4.0ms preprocess, 418.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 445.1ms
# Speed: 4.5ms preprocess, 445.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ CSV saved at: F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation\Scenario_1\Place_1\object_distances.csv
# 🔍 Processing Scenario_1, Place_2...
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 424.7ms
# Speed: 4.5ms preprocess, 424.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 416.5ms
# Speed: 5.3ms preprocess, 416.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 439.9ms
# Speed: 6.8ms preprocess, 439.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 413.7ms
# Speed: 6.6ms preprocess, 413.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 475.2ms
# Speed: 5.7ms preprocess, 475.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 440.9ms
# Speed: 4.8ms preprocess, 440.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 396.2ms
# Speed: 4.0ms preprocess, 396.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 410.9ms
# Speed: 4.5ms preprocess, 410.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 393.5ms
# Speed: 3.4ms preprocess, 393.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 411.6ms
# Speed: 2.3ms preprocess, 411.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 400.8ms
# Speed: 4.3ms preprocess, 400.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 413.1ms
# Speed: 3.0ms preprocess, 413.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 343.2ms
# Speed: 3.6ms preprocess, 343.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 473.9ms
# Speed: 4.4ms preprocess, 473.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 443.7ms
# Speed: 4.9ms preprocess, 443.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 403.0ms
# Speed: 4.8ms preprocess, 403.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 456.5ms
# Speed: 5.0ms preprocess, 456.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 476.7ms
# Speed: 4.5ms preprocess, 476.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 437.0ms
# Speed: 4.0ms preprocess, 437.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 461.0ms
# Speed: 5.2ms preprocess, 461.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 483.8ms
# Speed: 6.6ms preprocess, 483.8ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 443.5ms
# Speed: 4.6ms preprocess, 443.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 423.6ms
# Speed: 4.6ms preprocess, 423.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 463.0ms
# Speed: 6.1ms preprocess, 463.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 464.4ms
# Speed: 7.7ms preprocess, 464.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 468.5ms
# Speed: 6.8ms preprocess, 468.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 443.9ms
# Speed: 6.2ms preprocess, 443.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 422.6ms
# Speed: 4.6ms preprocess, 422.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 444.1ms
# Speed: 4.8ms preprocess, 444.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 457.9ms
# Speed: 8.1ms preprocess, 457.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 373.8ms
# Speed: 4.8ms preprocess, 373.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 437.2ms
# Speed: 6.0ms preprocess, 437.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 448.9ms
# Speed: 4.9ms preprocess, 448.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ CSV saved at: F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation\Scenario_1\Place_2\object_distances.csv
# 🔍 Processing Scenario_1, Place_3...
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 408.9ms
# Speed: 5.5ms preprocess, 408.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 434.6ms
# Speed: 5.3ms preprocess, 434.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 415.9ms
# Speed: 4.2ms preprocess, 415.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 417.9ms
# Speed: 4.1ms preprocess, 417.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 386.8ms
# Speed: 5.0ms preprocess, 386.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 392.5ms
# Speed: 4.1ms preprocess, 392.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 416.1ms
# Speed: 2.0ms preprocess, 416.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 361.1ms
# Speed: 2.8ms preprocess, 361.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 383.8ms
# Speed: 2.9ms preprocess, 383.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 408.8ms
# Speed: 3.9ms preprocess, 408.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 399.0ms
# Speed: 3.1ms preprocess, 399.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 378.9ms
# Speed: 4.0ms preprocess, 378.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 430.6ms
# Speed: 3.8ms preprocess, 430.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 426.3ms
# Speed: 4.6ms preprocess, 426.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 465.2ms
# Speed: 5.4ms preprocess, 465.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 445.0ms
# Speed: 5.1ms preprocess, 445.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 446.4ms
# Speed: 4.0ms preprocess, 446.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 381.8ms
# Speed: 3.9ms preprocess, 381.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 456.8ms
# Speed: 4.6ms preprocess, 456.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 461.9ms
# Speed: 5.7ms preprocess, 461.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 469.6ms
# Speed: 4.3ms preprocess, 469.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 426.5ms
# Speed: 7.0ms preprocess, 426.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 467.1ms
# Speed: 5.0ms preprocess, 467.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 406.4ms
# Speed: 6.3ms preprocess, 406.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 443.2ms
# Speed: 3.8ms preprocess, 443.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 315.0ms
# Speed: 3.9ms preprocess, 315.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 447.7ms
# Speed: 3.9ms preprocess, 447.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 470.8ms
# Speed: 4.5ms preprocess, 470.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 437.1ms
# Speed: 4.5ms preprocess, 437.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 427.7ms
# Speed: 4.8ms preprocess, 427.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 430.7ms
# Speed: 4.3ms preprocess, 430.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 404.1ms
# Speed: 6.8ms preprocess, 404.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 419.3ms
# Speed: 4.0ms preprocess, 419.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ CSV saved at: F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation\Scenario_1\Place_3\object_distances.csv
# 🔍 Processing Scenario_2, Place_1...
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 463.0ms
# Speed: 5.2ms preprocess, 463.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 443.2ms
# Speed: 5.0ms preprocess, 443.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 455.2ms
# Speed: 3.2ms preprocess, 455.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 470.0ms
# Speed: 5.3ms preprocess, 470.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 410.6ms
# Speed: 6.2ms preprocess, 410.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 382.0ms
# Speed: 6.1ms preprocess, 382.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 409.5ms
# Speed: 3.7ms preprocess, 409.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 321.6ms
# Speed: 3.5ms preprocess, 321.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 355.2ms
# Speed: 2.9ms preprocess, 355.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 385.6ms
# Speed: 2.6ms preprocess, 385.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 404.4ms
# Speed: 3.2ms preprocess, 404.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 403.4ms
# Speed: 2.9ms preprocess, 403.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 427.6ms
# Speed: 6.8ms preprocess, 427.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 369.2ms
# Speed: 3.3ms preprocess, 369.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 388.0ms
# Speed: 4.1ms preprocess, 388.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 419.1ms
# Speed: 4.1ms preprocess, 419.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 380.1ms
# Speed: 4.1ms preprocess, 380.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 381.4ms
# Speed: 4.1ms preprocess, 381.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 380.2ms
# Speed: 3.9ms preprocess, 380.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 349.8ms
# Speed: 3.9ms preprocess, 349.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 439.5ms
# Speed: 4.0ms preprocess, 439.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 458.1ms
# Speed: 3.6ms preprocess, 458.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 455.3ms
# Speed: 4.7ms preprocess, 455.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 440.8ms
# Speed: 3.0ms preprocess, 440.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 478.0ms
# Speed: 5.3ms preprocess, 478.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 471.7ms
# Speed: 3.9ms preprocess, 471.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 444.7ms
# Speed: 3.9ms preprocess, 444.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 434.5ms
# Speed: 3.7ms preprocess, 434.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 405.8ms
# Speed: 9.9ms preprocess, 405.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 367.4ms
# Speed: 3.3ms preprocess, 367.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 407.8ms
# Speed: 4.9ms preprocess, 407.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 429.1ms
# Speed: 3.4ms preprocess, 429.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 406.6ms
# Speed: 2.8ms preprocess, 406.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ CSV saved at: F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation\Scenario_2\Place_1\object_distances.csv
# 🔍 Processing Scenario_2, Place_2...
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 371.0ms
# Speed: 4.0ms preprocess, 371.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 426.9ms
# Speed: 2.8ms preprocess, 426.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 407.5ms
# Speed: 4.4ms preprocess, 407.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 407.2ms
# Speed: 4.4ms preprocess, 407.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 463.8ms
# Speed: 4.6ms preprocess, 463.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 438.3ms
# Speed: 4.5ms preprocess, 438.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 422.8ms
# Speed: 4.5ms preprocess, 422.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 405.3ms
# Speed: 3.7ms preprocess, 405.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 401.2ms
# Speed: 2.9ms preprocess, 401.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 414.9ms
# Speed: 3.9ms preprocess, 414.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 368.8ms
# Speed: 3.3ms preprocess, 368.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 368.8ms
# Speed: 3.8ms preprocess, 368.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 391.1ms
# Speed: 2.9ms preprocess, 391.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 368.6ms
# Speed: 3.3ms preprocess, 368.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 355.6ms
# Speed: 3.1ms preprocess, 355.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 382.1ms
# Speed: 3.6ms preprocess, 382.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 436.2ms
# Speed: 3.3ms preprocess, 436.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 464.7ms
# Speed: 4.9ms preprocess, 464.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 445.6ms
# Speed: 4.4ms preprocess, 445.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 473.1ms
# Speed: 4.3ms preprocess, 473.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 464.1ms
# Speed: 4.4ms preprocess, 464.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 456.0ms
# Speed: 4.7ms preprocess, 456.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 439.5ms
# Speed: 4.7ms preprocess, 439.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 437.1ms
# Speed: 4.1ms preprocess, 437.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 435.4ms
# Speed: 4.0ms preprocess, 435.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 464.0ms
# Speed: 4.4ms preprocess, 464.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 422.5ms
# Speed: 5.4ms preprocess, 422.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 449.7ms
# Speed: 5.2ms preprocess, 449.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 411.9ms
# Speed: 4.5ms preprocess, 411.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 438.8ms
# Speed: 3.9ms preprocess, 438.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 458.8ms
# Speed: 5.3ms preprocess, 458.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 434.5ms
# Speed: 4.1ms preprocess, 434.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 424.1ms
# Speed: 4.8ms preprocess, 424.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ CSV saved at: F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation\Scenario_2\Place_2\object_distances.csv
# 🔍 Processing Scenario_2, Place_3...
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 466.0ms
# Speed: 3.9ms preprocess, 466.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 465.6ms
# Speed: 4.4ms preprocess, 465.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 429.1ms
# Speed: 4.4ms preprocess, 429.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 465.0ms
# Speed: 4.6ms preprocess, 465.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 454.9ms
# Speed: 5.4ms preprocess, 454.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 432.1ms
# Speed: 5.0ms preprocess, 432.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 493.3ms
# Speed: 4.2ms preprocess, 493.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 388.5ms
# Speed: 3.8ms preprocess, 388.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 321.0ms
# Speed: 3.9ms preprocess, 321.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 357.1ms
# Speed: 3.9ms preprocess, 357.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 307.9ms
# Speed: 4.0ms preprocess, 307.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 392.7ms
# Speed: 2.7ms preprocess, 392.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 411.5ms
# Speed: 3.1ms preprocess, 411.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 392.4ms
# Speed: 4.2ms preprocess, 392.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 427.8ms
# Speed: 2.1ms preprocess, 427.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 431.6ms
# Speed: 2.6ms preprocess, 431.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 405.2ms
# Speed: 4.1ms preprocess, 405.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 428.5ms
# Speed: 4.0ms preprocess, 428.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 402.4ms
# Speed: 4.3ms preprocess, 402.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 399.2ms
# Speed: 3.7ms preprocess, 399.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 401.0ms
# Speed: 4.0ms preprocess, 401.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 352.4ms
# Speed: 3.4ms preprocess, 352.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 333.8ms
# Speed: 3.7ms preprocess, 333.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 404.9ms
# Speed: 3.6ms preprocess, 404.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 412.6ms
# Speed: 3.8ms preprocess, 412.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 398.1ms
# Speed: 4.2ms preprocess, 398.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 388.2ms
# Speed: 3.3ms preprocess, 388.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 427.2ms
# Speed: 4.2ms preprocess, 427.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 448.9ms
# Speed: 8.7ms preprocess, 448.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 358.2ms
# Speed: 3.9ms preprocess, 358.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 359.3ms
# Speed: 3.3ms preprocess, 359.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 378.3ms
# Speed: 3.9ms preprocess, 378.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 396.1ms
# Speed: 3.2ms preprocess, 396.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ CSV saved at: F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation\Scenario_2\Place_3\object_distances.csv
# 🔍 Processing Scenario_3, Place_1...
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 423.7ms
# Speed: 4.8ms preprocess, 423.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 403.8ms
# Speed: 4.6ms preprocess, 403.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 426.5ms
# Speed: 4.1ms preprocess, 426.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 415.0ms
# Speed: 3.8ms preprocess, 415.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 413.3ms
# Speed: 4.4ms preprocess, 413.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 412.3ms
# Speed: 4.9ms preprocess, 412.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 407.9ms
# Speed: 4.2ms preprocess, 407.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 420.4ms
# Speed: 4.1ms preprocess, 420.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 400.4ms
# Speed: 4.3ms preprocess, 400.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 448.0ms
# Speed: 4.4ms preprocess, 448.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 418.9ms
# Speed: 4.2ms preprocess, 418.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 424.4ms
# Speed: 4.6ms preprocess, 424.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 382.7ms
# Speed: 2.3ms preprocess, 382.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 401.3ms
# Speed: 4.2ms preprocess, 401.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 434.2ms
# Speed: 3.5ms preprocess, 434.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 434.1ms
# Speed: 4.0ms preprocess, 434.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 411.6ms
# Speed: 6.5ms preprocess, 411.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 426.7ms
# Speed: 3.9ms preprocess, 426.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ CSV saved at: F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation\Scenario_3\Place_1\object_distances.csv
# 🔍 Processing Scenario_3, Place_2...
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 452.6ms
# Speed: 5.5ms preprocess, 452.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 394.0ms
# Speed: 4.8ms preprocess, 394.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 460.1ms
# Speed: 4.0ms preprocess, 460.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 398.0ms
# Speed: 5.1ms preprocess, 398.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 399.2ms
# Speed: 4.1ms preprocess, 399.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 420.0ms
# Speed: 4.1ms preprocess, 420.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 394.1ms
# Speed: 5.5ms preprocess, 394.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 423.0ms
# Speed: 4.6ms preprocess, 423.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 448.6ms
# Speed: 3.9ms preprocess, 448.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 457.2ms
# Speed: 4.6ms preprocess, 457.2ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 420.9ms
# Speed: 3.9ms preprocess, 420.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 420.7ms
# Speed: 4.2ms preprocess, 420.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 383.4ms
# Speed: 3.6ms preprocess, 383.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 448.3ms
# Speed: 1.8ms preprocess, 448.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 402.9ms
# Speed: 4.1ms preprocess, 402.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 342.2ms
# Speed: 2.9ms preprocess, 342.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 394.2ms
# Speed: 2.9ms preprocess, 394.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 391.6ms
# Speed: 3.2ms preprocess, 391.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 388.5ms
# Speed: 3.1ms preprocess, 388.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 386.6ms
# Speed: 4.1ms preprocess, 386.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 428.3ms
# Speed: 2.9ms preprocess, 428.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 429.2ms
# Speed: 4.1ms preprocess, 429.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 451.3ms
# Speed: 5.5ms preprocess, 451.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 406.0ms
# Speed: 4.5ms preprocess, 406.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 393.3ms
# Speed: 4.6ms preprocess, 393.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 447.8ms
# Speed: 4.9ms preprocess, 447.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 413.0ms
# Speed: 3.9ms preprocess, 413.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 384.1ms
# Speed: 3.4ms preprocess, 384.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 397.3ms
# Speed: 4.0ms preprocess, 397.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 378.2ms
# Speed: 4.3ms preprocess, 378.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 384.3ms
# Speed: 2.9ms preprocess, 384.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 394.8ms
# Speed: 3.0ms preprocess, 394.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 415.9ms
# Speed: 3.1ms preprocess, 415.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ CSV saved at: F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation\Scenario_3\Place_2\object_distances.csv
# 🔍 Processing Scenario_3, Place_3...
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 410.6ms
# Speed: 4.2ms preprocess, 410.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 437.0ms
# Speed: 4.1ms preprocess, 437.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 383.7ms
# Speed: 2.8ms preprocess, 383.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 400.6ms
# Speed: 2.2ms preprocess, 400.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 418.5ms
# Speed: 3.9ms preprocess, 418.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 334.4ms
# Speed: 3.1ms preprocess, 334.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 371.4ms
# Speed: 3.9ms preprocess, 371.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 357.8ms
# Speed: 3.7ms preprocess, 357.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 378.4ms
# Speed: 2.9ms preprocess, 378.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 353.4ms
# Speed: 2.9ms preprocess, 353.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 370.7ms
# Speed: 2.5ms preprocess, 370.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 458.2ms
# Speed: 3.7ms preprocess, 458.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 395.6ms
# Speed: 3.4ms preprocess, 395.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 443.5ms
# Speed: 3.5ms preprocess, 443.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 406.8ms
# Speed: 3.8ms preprocess, 406.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 389.3ms
# Speed: 3.2ms preprocess, 389.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 406.4ms
# Speed: 3.0ms preprocess, 406.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 380.6ms
# Speed: 4.1ms preprocess, 380.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 430.9ms
# Speed: 2.3ms preprocess, 430.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 394.5ms
# Speed: 3.2ms preprocess, 394.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 390.9ms
# Speed: 3.0ms preprocess, 390.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 422.3ms
# Speed: 2.4ms preprocess, 422.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 361.2ms
# Speed: 2.4ms preprocess, 361.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 362.6ms
# Speed: 4.0ms preprocess, 362.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 364.0ms
# Speed: 2.5ms preprocess, 364.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 347.7ms
# Speed: 2.5ms preprocess, 347.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 396.4ms
# Speed: 2.2ms preprocess, 396.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 404.1ms
# Speed: 3.4ms preprocess, 404.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 385.9ms
# Speed: 3.1ms preprocess, 385.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 404.2ms
# Speed: 2.8ms preprocess, 404.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 378.0ms
# Speed: 2.8ms preprocess, 378.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 366.8ms
# Speed: 2.9ms preprocess, 366.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 AirPod, 1 Apple, 1 CardHolder, 1 Key, 1 Mobile, 1 Mouse, 1 Orange, 1 Stapler, 1 StickyNote, 1 Watch, 340.2ms
# Speed: 3.5ms preprocess, 340.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ CSV saved at: F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation\Scenario_3\Place_3\object_distances.csv

# %%
#Analysis and Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Base directory for the dataset
base_dir = r"F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation"

# Helper function to normalize names
normalize = lambda s: s.replace(" ", "").strip().lower()

# Store scenario-wise summary of average errors
summary_errors = {}

# Loop through scenarios and places
for scenario_id in range(1, 4):
    scenario_name = f"Scenario_{scenario_id}"
    scenario_errors = []

    for place_id in range(1, 4):
        place_name = f"Place_{place_id}"
        place_dir = os.path.join(base_dir, scenario_name, place_name)

        csv_path = os.path.join(place_dir, "object_distances.csv")
        gt_path = os.path.join(place_dir, "Ground_Truth_Distance.txt")

        if not os.path.exists(csv_path) or not os.path.exists(gt_path):
            print(f"⚠️ Skipping {scenario_name}/{place_name} — Missing files.")
            continue

        # Load CSV and skip first outlier row
        df = pd.read_csv(csv_path)
        df = df.iloc[1:]  # Remove the outlier row
        df_numeric = df.iloc[:, 1:]  # Remove image column

        # Normalize CSV columns
        normalized_csv_columns = [normalize(col) for col in df_numeric.columns]
        original_column_map = {normalize(col): col for col in df_numeric.columns}

        # Read all ground truth values into dictionary
        full_true_distances = {}
        with open(gt_path, "r") as f:
            for line in f:
                if ':' in line:
                    key, val = line.strip().split(":")
                    key_clean = normalize(key)
                    val_clean = val.strip().replace(",", "")
                    try:
                        full_true_distances[key_clean] = float(val_clean)
                    except ValueError:
                        print(f"⚠️ Skipping invalid value in {gt_path}: {line.strip()}")

        # Match columns from CSV with ground truth (after normalization)
        matched_keys = [col for col in normalized_csv_columns if col in full_true_distances]
        if not matched_keys:
            print(f"⚠️ No matching object columns found in {scenario_name}/{place_name}")
            continue

        # Prepare mappings
        matched_original_columns = [original_column_map[k] for k in matched_keys]
        matched_true_values = {original_column_map[k]: full_true_distances[k] for k in matched_keys}

        # Select columns and calculate error
        df_objects = df_numeric[matched_original_columns]
        error_df = abs(df_objects - pd.Series(matched_true_values))

        # Plot per-object error
        for obj in matched_original_columns:
            plt.figure(figsize=(10, 4))
            plt.plot(error_df.index, error_df[obj], label=f"{obj}", color='blue')
            plt.title(f"{scenario_name} - {place_name} - {obj}")
            plt.xlabel("Frame Index")
            plt.ylabel("Absolute Error (meters)")
            plt.grid(True)
            plt.legend()
            plot_file = os.path.join(place_dir, f"{scenario_name}_{place_name}_{obj}.png")
            plt.savefig(plot_file)
            plt.close()

        scenario_errors.append(error_df)

    # After all 3 places in a scenario
    if scenario_errors:
        combined_error_df = pd.concat(scenario_errors, ignore_index=True)
        avg_errors = combined_error_df.mean().sort_values()
        summary_errors[scenario_name] = avg_errors

        # Bar plot
        plt.figure(figsize=(10, 5))
        avg_errors.plot(kind='bar', color='skyblue')
        plt.title(f"Average Absolute Error per Object - {scenario_name}")
        plt.ylabel("Average Error (m)")
        plt.grid(True, axis='y')
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.savefig(os.path.join(base_dir, f"{scenario_name}_average_error_bar.png"))
        plt.close()

        # Heatmap
        plt.figure(figsize=(12, 6))
        sns.heatmap(combined_error_df.T, cmap="viridis", cbar_kws={'label': 'Absolute Error (m)'})
        plt.title(f"Error Heatmap - {scenario_name}")
        plt.xlabel("Frame Index")
        plt.ylabel("Object")
        plt.tight_layout()
        plt.savefig(os.path.join(base_dir, f"{scenario_name}_heatmap.png"))
        plt.close()

print("✅ All error plots and summaries saved successfully.")
# Out:
# ⚠️ No matching object columns found in Scenario_1/Place_1
# ⚠️ No matching object columns found in Scenario_1/Place_2
# ⚠️ No matching object columns found in Scenario_1/Place_3
# ⚠️ No matching object columns found in Scenario_2/Place_1
# ⚠️ No matching object columns found in Scenario_2/Place_2
# ⚠️ No matching object columns found in Scenario_2/Place_3
# ⚠️ No matching object columns found in Scenario_3/Place_1
# ⚠️ No matching object columns found in Scenario_3/Place_2
# ⚠️ No matching object columns found in Scenario_3/Place_3
# ✅ All error plots and summaries saved successfully.

# %%
import pandas as pd
import os

# Set directory and file paths
place_dir = r"F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation\Scenario_1\Place_1"
csv_path = os.path.join(place_dir, "object_distances.csv")
gt_path = os.path.join(place_dir, "Ground_Truth_Distance.txt")

# Read CSV and ignore first column
df = pd.read_csv(csv_path)
csv_columns = df.columns[1:]  # Skip 'image' column

print("📄 CSV Columns (excluding first column):")
print([col.strip() for col in csv_columns])

# Read ground truth keys, remove single quotes
gt_keys = []
with open(gt_path, "r") as f:
    for line in f:
        if ':' in line:
            key, _ = line.strip().split(":")
            key_clean = key.strip().replace("'", "")  # Remove single quotes
            gt_keys.append(key_clean)

print("\n📄 Ground Truth Keys (cleaned):")
print(gt_keys)
# Out:
# 📄 CSV Columns (excluding first column):
# ['apple', 'watch', 'airpods', 'cardholder', 'mouse', 'key', 'stapler', 'orange', 'phone', 'stickynote']
#
# 📄 Ground Truth Keys (cleaned):
# ['apple', 'watch', 'airpods', 'cardholder', 'mouse', 'key', 'stapler', 'orange', 'phone', 'stickynote']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Base directory
base_dir = r"F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation"

# Normalization helper
normalize = lambda s: s.replace(" ", "").replace("'", "").strip().lower()

# Dictionary to accumulate errors per scenario-object
scenario_object_errors = {}

# Loop through scenarios
for scenario_id in range(1, 4):
    scenario_name = f"Scenario_{scenario_id}"
    scenario_object_errors[scenario_name] = {}

    for place_id in range(1, 4):
        place_name = f"Place_{place_id}"
        place_dir = os.path.join(base_dir, scenario_name, place_name)

        csv_path = os.path.join(place_dir, "object_distances.csv")
        gt_path = os.path.join(place_dir, "Ground_Truth_Distance.txt")

        if not os.path.exists(csv_path) or not os.path.exists(gt_path):
            print(f"⚠️ Skipping {scenario_name}/{place_name} — Missing files.")
            continue

        # Load CSV, drop first row, and ignore first column
        df = pd.read_csv(csv_path)
        df = df.iloc[1:]  # Remove possible outlier
        df_numeric = df.iloc[:, 1:]

        # Normalize CSV columns
        original_columns = list(df_numeric.columns)
        normalized_csv_map = {normalize(col): col for col in original_columns}

        # Read and normalize ground truth
        true_distances = {}
        with open(gt_path, "r") as f:
            for line in f:
                if ':' in line:
                    key, val = line.strip().split(":")
                    key_clean = normalize(key)
                    val_clean = val.strip().replace(",", "")
                    try:
                        true_distances[key_clean] = float(val_clean)
                    except ValueError:
                        print(f"⚠️ Invalid value in GT: {line.strip()}")

        # Match columns in CSV with ground truth
        matched_keys = [k for k in normalized_csv_map if k in true_distances]
        matched_columns = [normalized_csv_map[k] for k in matched_keys]

        if not matched_columns:
            print(f"⚠️ No matching object columns found in {scenario_name}/{place_name}")
            continue

        df_objects = df_numeric[matched_columns]
        matched_true_values = {normalized_csv_map[k]: true_distances[k] for k in matched_keys}
        error_df = abs(df_objects - pd.Series(matched_true_values))

        # Store errors grouped by scenario and object
        for obj in matched_columns:
            if obj not in scenario_object_errors[scenario_name]:
                scenario_object_errors[scenario_name][obj] = []
            scenario_object_errors[scenario_name][obj].extend(error_df[obj].tolist())

# 🔧 Now generate plots for each object in each scenario
for scenario_name, object_errors in scenario_object_errors.items():
    for obj_name, error_values in object_errors.items():
        plt.figure(figsize=(10, 4))
        plt.plot(range(len(error_values)), error_values, label=obj_name, color='blue')
        plt.title(f"{scenario_name} - {obj_name} - Distance Error")
        plt.xlabel("Frame Index")
        plt.ylabel("Absolute Error (m)")
        plt.grid(True)
        plt.legend()
        output_plot_path = os.path.join(base_dir, f"{scenario_name}_{obj_name}_error_plot.png")
        plt.tight_layout()
        plt.savefig(output_plot_path)
        plt.close()

print("✅ All error plots generated successfully.")
# Out:
# ✅ All error plots generated successfully.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from collections import defaultdict

# Base directory for dataset
base_dir = r"F:\1 KFUPM\3rd Semester\Computer Vision\Assignment 3\Deliverable\Dataset\Before annotation"

# Normalization helper
normalize = lambda s: s.replace(" ", "").replace("'", "").strip().lower()

# To store scenario-level aggregation
scenario_object_errors = {}

# Loop through each scenario
for scenario_id in range(1, 4):
    scenario_name = f"Scenario_{scenario_id}"
    scenario_object_errors[scenario_name] = {}

    for place_id in range(1, 4):
        place_name = f"Place_{place_id}"
        place_dir = os.path.join(base_dir, scenario_name, place_name)

        csv_path = os.path.join(place_dir, "object_distances.csv")
        gt_path = os.path.join(place_dir, "Ground_Truth_Distance.txt")

        if not os.path.exists(csv_path) or not os.path.exists(gt_path):
            print(f"⚠️ Skipping {scenario_name}/{place_name} — Missing files.")
            continue

        # Load and clean CSV
        df = pd.read_csv(csv_path)
        df = df.iloc[1:]  # Remove potential outlier
        df_numeric = df.iloc[:, 1:]  # Ignore image column

        # Normalize CSV column names
        original_columns = list(df_numeric.columns)
        normalized_csv_map = {normalize(col): col for col in original_columns}

        # Read and normalize ground truth
        true_distances = {}
        with open(gt_path, "r") as f:
            for line in f:
                if ':' in line:
                    key, val = line.strip().split(":")
                    key_clean = normalize(key)
                    val_clean = val.strip().replace(",", "")
                    try:
                        true_distances[key_clean] = float(val_clean)
                    except ValueError:
                        print(f"⚠️ Invalid value in GT: {line.strip()}")

        # Match columns
        matched_keys = [k for k in normalized_csv_map if k in true_distances]
        matched_columns = [normalized_csv_map[k] for k in matched_keys]

        if not matched_columns:
            print(f"⚠️ No matching object columns found in {scenario_name}/{place_name}")
            continue

        df_objects = df_numeric[matched_columns]
        matched_true_values = {normalized_csv_map[k]: true_distances[k] for k in matched_keys}
        error_df = abs(df_objects - pd.Series(matched_true_values))

        # 🔹 Save object-wise plots per place
        for obj in matched_columns:
            error_values = error_df[obj].tolist()
            plt.figure(figsize=(10, 4))
            plt.plot(range(len(error_values)), error_values, label=obj, color='green')
            plt.title(f"{scenario_name} - {place_name} - {obj} Distance Error")
            plt.xlabel("Frame Index")
            plt.ylabel("Absolute Error (m)")
            plt.grid(True)
            plt.legend()
            plt.tight_layout()

            plot_path = os.path.join(place_dir, f"{scenario_name}_{place_name}_{obj}_error_plot.png")
            plt.savefig(plot_path)
            plt.close()

        # 🔹 Accumulate errors for scenario-level combination
        for obj in matched_columns:
            if obj not in scenario_object_errors[scenario_name]:
                scenario_object_errors[scenario_name][obj] = []
            scenario_object_errors[scenario_name][obj].extend(error_df[obj].tolist())

# ✅ Combined Plot for Each Object Across Scenarios with Custom Labels
# Rearranging for object -> scenario
object_scenario_errors = defaultdict(dict)

for scenario_name, obj_errors in scenario_object_errors.items():
    for obj_name, error_list in obj_errors.items():
        object_scenario_errors[obj_name][scenario_name] = error_list

# Custom legend labels
legend_labels = {
    "Scenario_1": "Frosted Glass",
    "Scenario_2": "Transparent Glass",
    "Scenario_3": "No Glass"
}

# Plot combined object-wise across scenarios
for obj_name, scenario_data in object_scenario_errors.items():
    plt.figure(figsize=(12, 5))

    for scenario_name, error_values in scenario_data.items():
        label = legend_labels.get(scenario_name, scenario_name)
        plt.plot(range(len(error_values)), error_values, label=label)

    plt.title(f"Distance Error for {obj_name} Across Scenarios")
    plt.xlabel("Frame Index")
    plt.ylabel("Absolute Error (m)")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()

    combined_plot_path = os.path.join(base_dir, f"{obj_name}_combined_error_plot.png")
    plt.savefig(combined_plot_path)
    plt.close()

print("✅ Place-wise and scenario-wise error plots generated successfully.")
# Out:
# ✅ Place-wise and scenario-wise error plots generated successfully.
